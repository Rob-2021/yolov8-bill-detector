# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47  Python-3.9.18 torch-2.1.1 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8187MiB)
# Setup complete  (16 CPUs, 15.9 GB RAM, 181.8/238.5 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd E:/yolov8DeteccionBilletes
# Out:
# E:\yolov8DeteccionBilletes

# %%
# !yolo task=detect mode=train model=yolov8l-seg.pt data= E:/yolov8DeteccionBilletes/data.yaml epochs=12 imgsz=640 batch=6 lr0=0.01 lrf=0.01 save=True save_period=1 exist_ok = True pretrained=True
# Out:
# ^C

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('E:\yolov8DeteccionBilletes\\runs\segment\\train\weights\last.pt')  # load a partially trained model

# Resume training
results = model.train(resume=True)
# Out:
# Ultralytics YOLOv8.1.47  Python-3.9.18 torch-2.1.1 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8187MiB)
# ...

# %%
Image(filename='E:\yolov8DeteccionBilletes\\runs\segment\\train\confusion_matrix.png', width=800)
